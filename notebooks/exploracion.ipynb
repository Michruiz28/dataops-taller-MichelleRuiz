# %%
import pandas as pd
import matplotlib.pyplot as plt
import sys
import os
sys.path.insert(0, os.path.abspath('src'))
from extract import extract_data
from transform import clean_data, calculate_metricas, agregar_ventas

# %%
df = extract_data('data/ventas.db')
df = clean_data(df)
df = calculate_metricas(df)
print(f"Total registros: {len(df)}")
print(df.head())

# %%
print(df.describe())

# %%
add = agregar_ventas(df)
print(add)

# %%
ventas_cat = df.groupby("categoria")["venta_total"].sum()
ventas_cat.plot(kind="bar", title="Ventas totales por categoría", color="pink")
plt.ylabel("Venta total")
plt.tight_layout()
plt.show()
